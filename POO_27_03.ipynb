# %% [markdown]
# <a href="https://colab.research.google.com/github/tom-locatelli47/Python/blob/main/POO_27_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Nós usamos o modificador de acesso private a fim de:
#
# b) Limitar o acesso às propriedades
#
# c) Limitar o acesso aos métodos
#
# d) B e C estão corretas

# %% [markdown]
# 2. Vamos voltar para a classe Usuario que desenvolvemos nas atividades anteriores. Agora vamos
# definir o primeiroNome do usuário como uma propriedade privada (private).
#
# Esta é a classe Usuario:
#
# class Usuario:
#   seu código vai aqui

# %% [markdown]
# 2.1 Crie uma propriedade na classe Usuario chamada primeiroNome e evite que qualquer código
# de fora da classe altere o seu valor, usando o modificador de acesso apropriado.

# %%
class Usuario():
  def __init__(self,primeiroNome = ""):
    self.__primeiroNome = primeiroNome

# %% [markdown]
# 2.2 Crie um método para definir o valor da propriedade primeiroNome. Use o modificador de
# acesso correto para ele.

# %%
class Usuario():
  def __init__(self,primeiroNome = ""):
    self.__primeiroNome = primeiroNome

  def setprimeiroNome(self,primeiroNome):
    self.__primeiroNome=primeiroNome

# %% [markdown]
# 2.3 Agora, crie um método para retornar o valor primeiroNome.

# %%
class Usuario():
  def __init__(self,primeiroNome = ""):
    self.__primeiroNome = primeiroNome

  def setprimeiroNome(self,primeiroNome):
    self.__primeiroNome=primeiroNome

  def getprimeiroNome(self):
    return f"O Primeiro nome é {self.__primeiroNome}"

# %% [markdown]
# 2.4 Crie um objeto chamado usuario1. Depois defina seu primeiro nome como "Joe" e faça com
# que ele retorne este nome.

# %%
usuario1=Usuario("Joe")
print(usuario1.getprimeiroNome())
# Out:
# O Primeiro nome é Joe

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Empregado:
  def __init__(self,nome,salario ,projeto):
    self.__nome = nome
    self.__salario = salario
    self.projeto = projeto

  def trabalho(self):
    return f"O {self.__nome} está trabalhando no projeto {self.projeto}"

  def mostrar(self):
    return f"Nome do Funcionario: {self.__nome}\nSalario: {self.__salario}"

  def setsalario(self,salario):
    self.__salario = salario

empregado1=Empregado("Ceasar", 5000, "Gate")


print(empregado1.trabalho())
print()
print(empregado1.mostrar())
# Out:
# O Ceasar está trabalhando no projeto Gate
#
# Nome do Funcionario: Ceasar
# Salario: 5000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Robo:
  def __init__(self,nome,ano_construcao):
    self.__nome = nome
    self.__ano_construcao = ano_construcao

  def diga_algo(self):
    return f"Robo: {self.__nome}\nConstruido em: {self.__ano_construcao}"

  def setano(self,ano_construcao):
    self.__ano_construcao = ano_construcao

  def getano(self):
    return f"Ano: {self.__ano_construcao}"

  def setnome(self,nome):
    self.__nome = nome

  def getano(self):
    return f"Nome: {self.__nome}"

robo1=Robo("R2D2",1957)

robo1.setano(1967)

robo1.setnome("BB8")

print(robo1.diga_algo())
# Out:
# Robo: BB8
# Construido em: 1967

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Laptop:
  def __init__(self,preco):
    self.__preco = preco

  def getpreco(self):
    return f"Preço: {self.__preco}"

  def setpreco(self,preco):
    self.__preco = preco

laptop=Laptop(2000)

laptop.setpreco(3999)

print(laptop.getpreco())
# Out:
# Preço: 3999

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Pessoa:
  def __init__(self,primeiroNome,ultimoNome):
    self.__primeiroNome = primeiroNome
    self.__ultimoNome = ultimoNome

  def getprimeiroNome(self):
    return f"Primeiro nome: {self.__primeiroNome}"

  def setprimeiroNome(self,primeiroNome):
    self.__primeiroNome = primeiroNome


  def setultimoNome(self,ultimoNome):
    self.__ultimoNome = ultimoNome

  def getultimoNome(self):
    return f"Primeiro nome: {self.__ultimoNome}"

pessoa=Pessoa("JOJO","Joestar")

pessoa.setprimeiroNome("João")
pessoa.setultimoNome("Carvalho")

print(pessoa.getprimeiroNome())
print(pessoa.getultimoNome())
# Out:
# Primeiro nome: João
# Primeiro nome: Carvalho
