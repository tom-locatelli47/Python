# %% [markdown]
# <a href="https://colab.research.google.com/github/tom-locatelli47/Python/blob/main/POO_aula_Polimorfismo_24_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Usuario:
  pontos = 0
  numeroDeArtigos = 0

# Métodos vão aqui

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Usuario:
  pontos = 0
  numeroDeArtigos = 0

  def setNumberDeArtigos(self,nart):
    numeroDeArtigos = int(nart)

  def getNumeroDeArtigos(self):
    return self.numeroDeArtigos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Usuario:
  pontos = 0
  numeroDeArtigos = 0

  def setNumberDeArtigos(self,nart):
    numeroDeArtigos = int(nart)

  def getNumeroDeArtigos(self):
    return self.numeroDeArtigos

  def calcPontuacao(self):
    pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Usuario():
  pontos = 0
  numeroDeArtigos = 0

  def setNumberDeArtigos(self,nart):
    numeroDeArtigos = int(nart)

  def getNumeroDeArtigos(self):
    return self.numeroDeArtigos

  def calcPontuacao(self):
    pass

class Autor(Usuario):
  def calcPontuacao(self):
    return self.numeroDeArtigos * 10 + 20

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Usuario():
  pontos = 0
  numeroDeArtigos = 0

  def setNumberDeArtigos(self,nart):
    self.numeroDeArtigos = int(nart)

  def getNumeroDeArtigos(self):
    return self.numeroDeArtigos

  def calcPontuacao(self):
    pass

class Autor(Usuario):
  def calcPontuacao(self):
    return self.numeroDeArtigos * 10 + 20

class Editor(Usuario):
  def calcPontuacao(self):
    return self.numeroDeArtigos * 6 + 15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
autor1 = Autor()
autor1.setNumberDeArtigos(8)
print(autor1.calcPontuacao())
# Out:
# 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
editor1 = Autor()
editor1.setNumberDeArtigos(15)
print(editor1.calcPontuacao())
# Out:
# 170
